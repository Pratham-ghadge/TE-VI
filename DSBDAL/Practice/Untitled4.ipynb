# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('IRIS.csv')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species             str
# dtype: object

# %%
sns.histplot( x=df['sepal_length'], kde=True)
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot( x=df['sepal_width'], kde=True)
# Out:
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width'], dtype='str')

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
sns.pairplot(df)

# %%
 for i in df.columns:
     plt.figure(figsize=(4,6))
     sns.distplot(df[i],kde=True)
     plt.title(i)
     plt.show()
# Out:
# /tmp/ipykernel_80455/1195931632.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i],kde=True)
# /tmp/ipykernel_80455/1195931632.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i],kde=True)
# /tmp/ipykernel_80455/1195931632.py:3: UserWarning:
#
# ...

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width'], dtype='str')

# %%
df= sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 1         1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2         1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3         1       1  female  35.0  ...     C  Southampton    yes  False
# 4         0       3    male  35.0  ...   NaN  Southampton     no   True
#
# [5 rows x 15 columns]

# %%
sns.boxplot(data=df , x='sex',y='age',hue='survived')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.histplot(df['fare'] ,kde=True)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
# types of plot reletional 
sns.scatterplot(y='fare',x='age',data=df)
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sns.lineplot(y='fare',x='age',data=df,hue='survived')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
## categorical
sns.boxplot(x='pclass',y='fare',hue = 'survived' ,data=df)
# Out:
# <Axes: xlabel='pclass', ylabel='fare'>

# %%
sns.catplot(x='pclass',y='fare',hue = 'survived' ,data=df)

# %%
sns.countplot(x='pclass',hue = 'survived' ,data=df)
# Out:
# <Axes: xlabel='pclass', ylabel='count'>

# %%
sns.violinplot(x='sex',y='age',hue = 'survived' ,data=df)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.swarmplot(x='sex',y='age',hue = 'survived' ,data=df)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
# distribution
sns.histplot(df['age'])
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.distplot(df['fare'])
# Out:
# /tmp/ipykernel_80455/1195996103.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['fare'])
# <Axes: xlabel='fare', ylabel='Density'>

# %%
sns.rugplot(df['age'])
# Out:
# <Axes: xlabel='age'>

# %%
# regression plot

# %%
# matrix plot
col = df.select_dtypes(include=['int64','float'])
col.head()
# Out:
#    survived  pclass   age  sibsp  parch     fare
# 0         0       3  22.0      1      0   7.2500
# 1         1       1  38.0      1      0  71.2833
# 2         1       3  26.0      0      0   7.9250
# 3         1       1  35.0      1      0  53.1000
# 4         0       3  35.0      0      0   8.0500

# %%
sns.heatmap(col.corr(),annot=True,cmap='rainbow')
# Out:
# <Axes: >

# %%
sns.pairplot(df)
